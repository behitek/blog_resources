# %% [markdown]
# # Convolutional Neural Network Example
# Ví dụ này sử dụng mô hình CNN để huấn luyện dữ liệu MNIST

# %%
from __future__ import division, print_function, absolute_import

import tensorflow as tf
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# Các tham số huấn luyện
learning_rate = 0.001
num_steps = 500
batch_size = 128
display_step = 10

# Tham số của mạng
num_input = 784 # MNIST data input (img shape: 28*28)
num_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# Khai báo placeholder cho input của model
X = tf.placeholder(tf.float32, [None, num_input])
Y = tf.placeholder(tf.float32, [None, num_classes])
keep_prob = tf.placeholder(tf.float32) # dropout (keep probability)

# %%
# Lớp conv 2d
# padding SAME là giữ kích thước của output giống input.
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # MNIST data input is a 1-D vector of 784 features (28*28 pixels)
    # Reshape to match picture format [Height x Width x Channel]
    # Tensor input become 4-D: [Batch Size, Height, Width, Channel]
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, num_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([num_classes]))
}

# Construct model
logits = conv_net(X, weights, biases, keep_prob)
prediction = tf.nn.softmax(logits)

# Define loss and optimizer
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
    logits=logits, labels=Y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)


# Evaluate model
correct_pred = tf.equal(tf.argmax(prediction, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()
# Out:
# WARNING:tensorflow:From <ipython-input-5-3814cdbf73dc>:26: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %%
# Start training
with tf.Session() as sess:

    # Run the initializer
    sess.run(init)

    for step in range(1, num_steps+1):
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(train_op, feed_dict={X: batch_x, Y: batch_y, keep_prob: dropout})
        if step % display_step == 0 or step == 1:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([loss_op, accuracy], feed_dict={X: batch_x,
                                                                 Y: batch_y,
                                                                 keep_prob: 1.0})
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.3f}".format(acc))

    print("Optimization Finished!")

    # Calculate accuracy for 256 MNIST test images
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={X: mnist.test.images[:256],
                                      Y: mnist.test.labels[:256],
                                      keep_prob: 1.0}))
# Out:
# Step 1, Minibatch Loss= 69803.5156, Training Accuracy= 0.133
# Step 10, Minibatch Loss= 23523.8164, Training Accuracy= 0.297
# Step 20, Minibatch Loss= 11735.0059, Training Accuracy= 0.469
# Step 30, Minibatch Loss= 7353.4185, Training Accuracy= 0.656
# Step 40, Minibatch Loss= 6400.4307, Training Accuracy= 0.711
# Step 50, Minibatch Loss= 4759.3203, Training Accuracy= 0.766
# Step 60, Minibatch Loss= 4263.3691, Training Accuracy= 0.742
# Step 70, Minibatch Loss= 2817.6348, Training Accuracy= 0.883
# Step 80, Minibatch Loss= 4701.4600, Training Accuracy= 0.812
# Step 90, Minibatch Loss= 2675.2493, Training Accuracy= 0.859
# Step 100, Minibatch Loss= 2779.4111, Training Accuracy= 0.859
# Step 110, Minibatch Loss= 2392.6011, Training Accuracy= 0.875
# Step 120, Minibatch Loss= 3552.3730, Training Accuracy= 0.820
# Step 130, Minibatch Loss= 2127.6731, Training Accuracy= 0.883
# Step 140, Minibatch Loss= 1770.1375, Training Accuracy= 0.898
# Step 150, Minibatch Loss= 939.4228, Training Accuracy= 0.922
# Step 160, Minibatch Loss= 2581.5117, Training Accuracy= 0.914
# Step 170, Minibatch Loss= 1731.4102, Training Accuracy= 0.898
# Step 180, Minibatch Loss= 1440.5642, Training Accuracy= 0.898
# Step 190, Minibatch Loss= 956.1677, Training Accuracy= 0.922
# Step 200, Minibatch Loss= 1617.1528, Training Accuracy= 0.891
# Step 210, Minibatch Loss= 1197.3829, Training Accuracy= 0.922
# Step 220, Minibatch Loss= 1133.5168, Training Accuracy= 0.945
# Step 230, Minibatch Loss= 1587.0596, Training Accuracy= 0.906
# Step 240, Minibatch Loss= 1766.6975, Training Accuracy= 0.891
# Step 250, Minibatch Loss= 1476.4573, Training Accuracy= 0.922
# Step 260, Minibatch Loss= 1424.2615, Training Accuracy= 0.914
# Step 270, Minibatch Loss= 664.8875, Training Accuracy= 0.938
# Step 280, Minibatch Loss= 728.9406, Training Accuracy= 0.953
# Step 290, Minibatch Loss= 1217.5928, Training Accuracy= 0.938
# Step 300, Minibatch Loss= 1508.0583, Training Accuracy= 0.914
# Step 310, Minibatch Loss= 864.6277, Training Accuracy= 0.945
# Step 320, Minibatch Loss= 769.2131, Training Accuracy= 0.938
# Step 330, Minibatch Loss= 687.2493, Training Accuracy= 0.930
# Step 340, Minibatch Loss= 316.4153, Training Accuracy= 0.945
# Step 350, Minibatch Loss= 1576.1875, Training Accuracy= 0.914
# Step 360, Minibatch Loss= 743.2999, Training Accuracy= 0.930
# Step 370, Minibatch Loss= 507.2176, Training Accuracy= 0.961
# Step 380, Minibatch Loss= 399.3603, Training Accuracy= 0.961
# Step 390, Minibatch Loss= 749.0842, Training Accuracy= 0.953
# Step 400, Minibatch Loss= 998.4781, Training Accuracy= 0.938
# Step 410, Minibatch Loss= 1289.3295, Training Accuracy= 0.930
# Step 420, Minibatch Loss= 280.4218, Training Accuracy= 0.953
# Step 430, Minibatch Loss= 799.4011, Training Accuracy= 0.969
# Step 440, Minibatch Loss= 728.9257, Training Accuracy= 0.969
# Step 450, Minibatch Loss= 857.0018, Training Accuracy= 0.922
# Step 460, Minibatch Loss= 652.6086, Training Accuracy= 0.961
# Step 470, Minibatch Loss= 682.5320, Training Accuracy= 0.938
# Step 480, Minibatch Loss= 524.4694, Training Accuracy= 0.961
# Step 490, Minibatch Loss= 576.5222, Training Accuracy= 0.961
# Step 500, Minibatch Loss= 700.5278, Training Accuracy= 0.930
# Optimization Finished!
# Testing Accuracy: 0.96875
