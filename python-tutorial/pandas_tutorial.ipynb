# %% [markdown]
# # Pandas tutorial
# Thư viện pandas python - Hướng dẫn sử dụng thư viện pandas trong python cho người mới bắt đầu
#
# Đây là source code của bài học thư viện pandas của blog học lập trình cùng Nguyễn Văn Hiếu
#
# Xem chi tiết tại: https://nguyenvanhieu.vn/thu-vien-pandas-python

# %%
# Render our plots inline
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Đọc file csv

# %%
peoples_df = pd.read_csv('./people.csv')
peoples_df.head(5)
# Out:
#    person_ID                 name    first    last  middle             email  \
# 0       3130      Burks, Rosella   Rosella   Burks     NaN   BurksR@univ.edu
# 1       3297       Avila, Damien    Damien   Avila     NaN   AvilaD@univ.edu
# 2       3547        Olsen, Robin     Robin   Olsen     NaN   OlsenR@univ.edu
# 3       1538  Moises, Edgar Estes    Edgar  Moises   Estes  MoisesE@univ.edu
# 4       2941  Brian, Heath Pruitt    Heath   Brian  Pruitt   BrianH@univ.edu
#
#                phone           fax                title  age
# 0       963.555.1253  963.777.4065            Professor   25
# 1       963.555.1352  963.777.7914           Professor    23
# 2       963.555.1378  963.777.9262  Assistant Professor   21
# 3  963.555.2731x3565  963.777.8264            Professor   18
# 4       963.555.2800  963.777.7249   Associate Curator    30

# %%
peoples_df = pd.read_csv('./people.csv', encoding='utf-8', header='infer', sep=',')
# Lấy 5 bản ghi đầu tiên
peoples_df.head(5)
# Out:
#    person_ID                 name    first    last  middle             email  \
# 0       3130      Burks, Rosella   Rosella   Burks     NaN   BurksR@univ.edu
# 1       3297       Avila, Damien    Damien   Avila     NaN   AvilaD@univ.edu
# 2       3547        Olsen, Robin     Robin   Olsen     NaN   OlsenR@univ.edu
# 3       1538  Moises, Edgar Estes    Edgar  Moises   Estes  MoisesE@univ.edu
# 4       2941  Brian, Heath Pruitt    Heath   Brian  Pruitt   BrianH@univ.edu
#
#                phone           fax                title  age
# 0       963.555.1253  963.777.4065            Professor   25
# 1       963.555.1352  963.777.7914           Professor    23
# 2       963.555.1378  963.777.9262  Assistant Professor   21
# 3  963.555.2731x3565  963.777.8264            Professor   18
# 4       963.555.2800  963.777.7249   Associate Curator    30

# %%
# Xem thông tin dataframe vừa đọc được
print('Len:', len(peoples_df))
peoples_df.info()
# Xem kích thước của dataframe
print('Shape:', peoples_df.shape)
# Out:
# Len: 40
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 11 columns):
# person_ID    40 non-null int64
# name         40 non-null object
# first        40 non-null object
# last         40 non-null object
# middle       15 non-null object
# email        40 non-null object
# phone        40 non-null object
# fax          40 non-null object
# title        40 non-null object
# age          40 non-null int64
# is_young     40 non-null bool
# dtypes: bool(1), int64(2), object(8)
# memory usage: 3.2+ KB
# Shape: (40, 11)

# %%
# Lấy một cột của dataframe
peoples_df['age']
# Out:
# 0     25
# 1     23
# 2     21
# 3     18
# 4     30
# 5     35
# 6     35
# 7     35
# 8     29
# 9     29
# 10    28
# 11    23
# 12    22
# 13    22
# 14    25
# 15    24
# 16    25
# 17    25
# 18    25
# 19    25
# 20    28
# 21    28
# 22    28
# 23    28
# 24    28
# 25    25
# 26    25
# 27    25
# 28    25
# 29    25
# 30    25
# 31    25
# 32    25
# 33    25
# 34    25
# 35    25
# 36    25
# 37    25
# 38    25
# 39    25
# Name: age, dtype: int64

# %% [markdown]
# ### Lấy nhiều cột

# %%
peoples_df[['name', 'age']].head(5)
# Out:
#                   name  age
# 0      Burks, Rosella    25
# 1       Avila, Damien    23
# 2        Olsen, Robin    21
# 3  Moises, Edgar Estes   18
# 4  Brian, Heath Pruitt   30

# %%
# Sử dụng slice để lấy các bản ghi
peoples_df[0:5]
# Out:
#    person_ID  name    first    last  middle             email  \
# 0       3130  None  Rosella   Burks     NaN   BurksR@univ.edu
# 1       3297  None   Damien   Avila     NaN   AvilaD@univ.edu
# 2       3547  None    Robin   Olsen     NaN   OlsenR@univ.edu
# 3       1538  None    Edgar  Moises   Estes  MoisesE@univ.edu
# 4       2941  None    Heath   Brian  Pruitt   BrianH@univ.edu
#
#                phone           fax                title  age  is_young  \
# 0       963.555.1253  963.777.4065            Professor   25     False
# 1       963.555.1352  963.777.7914           Professor    23      True
# 2       963.555.1378  963.777.9262  Assistant Professor   21      True
# 3  963.555.2731x3565  963.777.8264            Professor   18      True
# 4       963.555.2800  963.777.7249   Associate Curator    30     False
#
#    birthday
# 0      1985
# 1      1980
# 2      1983
# 3      1984
# 4      1997

# %% [markdown]
# ### Kết hợp lấy nhiều cột và bản ghi

# %%
peoples_df[['name', 'age']][:5]
# Out:
#    name  age
# 0  None   25
# 1  None   23
# 2  None   21
# 3  None   18
# 4  None   30

# %% [markdown]
# ### Sử dụng kết hợp điều kiện

# %%
young_pp = peoples_df[peoples_df['age'] < 25]
young_pp[:5]
# Out:
#     person_ID  name     first      last  middle               email  \
# 1        3297  None    Damien     Avila     NaN     AvilaD@univ.edu
# 2        3547  None     Robin     Olsen     NaN     OlsenR@univ.edu
# 3        1538  None     Edgar    Moises   Estes    MoisesE@univ.edu
# 11       2755  None      Reba  Kendrick  Alford  KendrickR@univ.edu
# 12       4150  None  Angelina      Sims     NaN      SimsA@univ.edu
#
#                 phone           fax                title  age  is_young  \
# 1        963.555.1352  963.777.7914           Professor    23      True
# 2        963.555.1378  963.777.9262  Assistant Professor   21      True
# 3   963.555.2731x3565  963.777.8264            Professor   18      True
# 11  963.555.4618x7744  963.777.4371   Associate Curator    23      True
# 12       963.555.5278  963.777.4400            Professor   22      True
#
#     birthday
# 1       1980
# 2       1983
# 3       1984
# 11      1993
# 12      1983

# %% [markdown]
# ### Thêm bản ghi dựa vào dữ liệu gốc

# %%
peoples_df['is_young'] = peoples_df['age'] < 25
peoples_df.head(5)
# Out:
#    person_ID                 name    first    last  middle             email  \
# 0       3130      Burks, Rosella   Rosella   Burks     NaN   BurksR@univ.edu
# 1       3297       Avila, Damien    Damien   Avila     NaN   AvilaD@univ.edu
# 2       3547        Olsen, Robin     Robin   Olsen     NaN   OlsenR@univ.edu
# 3       1538  Moises, Edgar Estes    Edgar  Moises   Estes  MoisesE@univ.edu
# 4       2941  Brian, Heath Pruitt    Heath   Brian  Pruitt   BrianH@univ.edu
#
#                phone           fax                title  age  is_young
# 0       963.555.1253  963.777.4065            Professor   25     False
# 1       963.555.1352  963.777.7914           Professor    23      True
# 2       963.555.1378  963.777.9262  Assistant Professor   21      True
# 3  963.555.2731x3565  963.777.8264            Professor   18      True
# 4       963.555.2800  963.777.7249   Associate Curator    30     False

# %% [markdown]
# ### Tìm kiếm bản ghi thỏa mãn điều kiện

# %%
professor = peoples_df[peoples_df.title == 'Professor']
professor.head(5)
# Out:
#     person_ID                 name     first     last middle  \
# 0        3130      Burks, Rosella    Rosella    Burks    NaN
# 3        1538  Moises, Edgar Estes     Edgar   Moises  Estes
# 8        1625     Hawkins, Callie     Callie  Hawkins    NaN
# 9        1307        Pate, Andrea     Andrea     Pate    NaN
# 12       4150      Sims, Angelina   Angelina     Sims    NaN
#
#                 email              phone           fax      title  age  \
# 0     BurksR@univ.edu       963.555.1253  963.777.4065  Professor   25
# 3    MoisesE@univ.edu  963.555.2731x3565  963.777.8264  Professor   18
# 8   HawkinsC@univ.edu  963.555.3350x6480  963.777.4949  Professor   29
# 9      PateA@univ.edu       963.555.3723  963.777.5049  Professor   29
# 12     SimsA@univ.edu       963.555.5278  963.777.4400  Professor   22
#
#     is_young
# 0      False
# 3       True
# 8      False
# 9      False
# 12      True

# %%
name_compare = peoples_df['name'].str.contains('Rosella')
name_compare.head(5)
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# Name: name, dtype: object

# %% [markdown]
# ### Lấy giá trị của cột trả về numpy array

# %%
peoples_df['name'].values
# Out:
# array(['Burks, Rosella ', 'Avila, Damien ', 'Olsen, Robin ',
#        'Moises, Edgar Estes', 'Brian, Heath Pruitt',
#        'Claude, Elvin Haney', 'Mosley, Edmund ', 'Derek, Antoine Mccoy',
#        'Hawkins, Callie ', 'Pate, Andrea ', 'Austin, Liz ',
#        'Kendrick, Reba Alford', 'Sims, Angelina ', 'Mullins, Kimberly ',
#        'Chuck, Lloyd Haney', 'Payne, Ladonna ',
#        'Baxter, Johnathan Browning', 'Weiss, Gilbert ',
#        'Deirdre, Florence Barrera', 'Fernando, Toby Calderon',
#        'Garrison, Patrica ', 'Effie, Leila Vinson', 'Buckley, Rose ',
#        'Stanton, Kathie ', 'Banks, Shannon ', 'Barnes, Cleo ',
#        'Brady, Nellie ', 'Katheryn, Ruben Holt', 'Michael, Dianne ',
#        'Grant, Adam ', 'Head, Kurtis ', 'Berger, Jami ',
#        'Earline, Jaime Fitzgerald', 'Evelyn, Summer Frost',
#        'Quentin, Sam Hyde', 'Dunlap, Ann ', 'Shields, Rich Pena',
#        'Page, Winnie ', 'Sparks, Ezra ', 'Kaufman, Elba '], dtype=object)

# %%
df_len = len(peoples_df)
birthday = [random.randrange(1980, 2000, 1) for i in range(df_len)]
peoples_df['birthday'] = birthday
peoples_df.tail(5)
# Out:
#     person_ID  name   first     last middle              email         phone  \
# 35       3903  None     Ann   Dunlap    NaN   DunlapA@univ.edu  963.555.9067
# 36       3095  None    Rich  Shields   Pena  ShieldsR@univ.edu  963.555.9197
# 37       2383  None  Winnie     Page    NaN     PageW@univ.edu  963.555.9366
# 38       2146  None    Ezra   Sparks    NaN   SparksE@univ.edu  963.555.9390
# 39       3958  None    Elba  Kaufman    NaN  KaufmanE@univ.edu  963.555.9507
#
#              fax                title  age  is_young  birthday
# 35  963.777.4290  Assistant Professor   25     False      1989
# 36  963.777.7215           Professor    25     False      1988
# 37  963.777.3202              Curator   25     False      1999
# 38  963.777.9273  Assistant Professor   25     False      1982
# 39  963.777.3298            Professor   25     False      1989

# %%
peoples_df['name'][0] = 'Hiếu'
peoples_df.head(4)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    person_ID                 name    first    last middle             email  \
# 0       3130                 Hiếu  Rosella   Burks    NaN   BurksR@univ.edu
# 1       3297       Avila, Damien    Damien   Avila    NaN   AvilaD@univ.edu
# 2       3547        Olsen, Robin     Robin   Olsen    NaN   OlsenR@univ.edu
# 3       1538  Moises, Edgar Estes    Edgar  Moises  Estes  MoisesE@univ.edu
#
#                phone           fax                title  age  is_young
# 0       963.555.1253  963.777.4065            Professor   25     False
# 1       963.555.1352  963.777.7914           Professor    23      True
# 2       963.555.1378  963.777.9262  Assistant Professor   21      True
# 3  963.555.2731x3565  963.777.8264            Professor   18      True

# %%
peoples_df['new_column'] = None
peoples_df
# Out:
#     person_ID                        name      first      last      middle  \
# 0        3130             Burks, Rosella     Rosella     Burks         NaN
# 1        3297              Avila, Damien      Damien     Avila         NaN
# 2        3547               Olsen, Robin       Robin     Olsen         NaN
# 3        1538         Moises, Edgar Estes      Edgar    Moises       Estes
# 4        2941         Brian, Heath Pruitt      Heath     Brian      Pruitt
# 5        2401         Claude, Elvin Haney      Elvin    Claude       Haney
# 6        2070             Mosley, Edmund      Edmund    Mosley         NaN
# 7        2561        Derek, Antoine Mccoy    Antoine     Derek       Mccoy
# 8        1625            Hawkins, Callie      Callie   Hawkins         NaN
# 9        1307               Pate, Andrea      Andrea      Pate         NaN
# 10       2342                Austin, Liz         Liz    Austin         NaN
# 11       2755       Kendrick, Reba Alford       Reba  Kendrick      Alford
# 12       4150             Sims, Angelina    Angelina      Sims         NaN
# 13       3544          Mullins, Kimberly    Kimberly   Mullins         NaN
# 14       2096          Chuck, Lloyd Haney      Lloyd     Chuck       Haney
# 15       1089             Payne, Ladonna     Ladonna     Payne         NaN
# 16       2948  Baxter, Johnathan Browning  Johnathan    Baxter    Browning
# 17       4539             Weiss, Gilbert     Gilbert     Weiss         NaN
# 18       2811   Deirdre, Florence Barrera   Florence   Deirdre     Barrera
# 19       4580     Fernando, Toby Calderon       Toby  Fernando    Calderon
# 20       2895          Garrison, Patrica     Patrica  Garrison         NaN
# 21       2254         Effie, Leila Vinson      Leila     Effie      Vinson
# 22       2389              Buckley, Rose        Rose   Buckley         NaN
# 23       1699            Stanton, Kathie      Kathie   Stanton         NaN
# 24       1567             Banks, Shannon     Shannon     Banks         NaN
# 25       3066               Barnes, Cleo        Cleo    Barnes         NaN
# 26       2426              Brady, Nellie      Nellie     Brady         NaN
# 27       2217        Katheryn, Ruben Holt      Ruben  Katheryn        Holt
# 28       1968            Michael, Dianne      Dianne   Michael         NaN
# 29       3012                Grant, Adam        Adam     Grant         NaN
# 30       1824               Head, Kurtis      Kurtis      Head         NaN
# 31       3929               Berger, Jami        Jami    Berger         NaN
# 32       2682   Earline, Jaime Fitzgerald      Jaime   Earline  Fitzgerald
# 33       3112        Evelyn, Summer Frost     Summer    Evelyn       Frost
# 34       2303           Quentin, Sam Hyde        Sam   Quentin        Hyde
# 35       3903                Dunlap, Ann         Ann    Dunlap         NaN
# 36       3095          Shields, Rich Pena       Rich   Shields        Pena
# 37       2383               Page, Winnie      Winnie      Page         NaN
# 38       2146               Sparks, Ezra        Ezra    Sparks         NaN
# 39       3958              Kaufman, Elba        Elba   Kaufman         NaN
#
#                  email              phone           fax                title  \
# 0      BurksR@univ.edu       963.555.1253  963.777.4065            Professor
# 1      AvilaD@univ.edu       963.555.1352  963.777.7914           Professor
# 2      OlsenR@univ.edu       963.555.1378  963.777.9262  Assistant Professor
# 3     MoisesE@univ.edu  963.555.2731x3565  963.777.8264            Professor
# 4      BrianH@univ.edu       963.555.2800  963.777.7249   Associate Curator
# 5     ClaudeE@univ.edu       963.555.2902  963.777.9730              Curator
# 6     MosleyE@univ.edu       963.555.2945  963.777.9285  Assistant Professor
# 7      DerekA@univ.edu       963.555.2992  963.777.5454              Curator
# 8    HawkinsC@univ.edu  963.555.3350x6480  963.777.4949            Professor
# 9       PateA@univ.edu       963.555.3723  963.777.5049            Professor
# 10    AustinL@univ.edu       963.555.4305  963.777.6143  Assistant Professor
# 11  KendrickR@univ.edu  963.555.4618x7744  963.777.4371   Associate Curator
# 12      SimsA@univ.edu       963.555.5278  963.777.4400            Professor
# 13   MullinsK@univ.edu  963.555.5471x1017  963.777.9783  Assistant Professor
# 14     ChuckL@univ.edu  963.555.5568x2652  963.777.9290  Assistant Professor
# 15     PayneL@univ.edu       963.555.5639  963.777.6469            Professor
# 16    BaxterJ@univ.edu       963.555.5902  963.777.8336   Research Professor
# 17     WeissG@univ.edu       963.555.5969  963.777.4975            Professor
# 18   DeirdreF@univ.edu       963.555.6319  963.777.9654   Associate Curator
# 19  FernandoT@univ.edu       963.555.6469  963.777.9864   Research Professor
# 20  GarrisonP@univ.edu       963.555.6760  963.777.4958   Associate Curator
# 21     EffieL@univ.edu       963.555.6824  963.777.7299  Assistant Professor
# 22   BuckleyR@univ.edu  963.555.6855x5018  963.777.5233              Curator
# 23   StantonK@univ.edu       963.555.7095  963.777.1015            Professor
# 24     BanksS@univ.edu       963.555.7198  963.777.6979            Professor
# 25    BarnesC@univ.edu  963.555.7463x7335  963.777.1583   Research Professor
# 26     BradyN@univ.edu       963.555.7569  963.777.7218              Curator
# 27  KatherynR@univ.edu       963.555.7578  963.777.3969  Assistant Professor
# 28   MichaelD@univ.edu       963.555.7592  963.777.9960  Assistant Professor
# 29     GrantA@univ.edu       963.555.7775  963.777.8115   Research Professor
# 30      HeadK@univ.edu       963.555.7882  963.777.6348            Professor
# 31    BergerJ@univ.edu       963.555.8158  963.777.5650   Research Professor
# 32   EarlineJ@univ.edu       963.555.8357  963.777.4114   Associate Curator
# 33    EvelynS@univ.edu       963.555.8895  963.777.5730           Professor
# 34   QuentinS@univ.edu       963.555.8921  963.777.2712  Assistant Professor
# 35    DunlapA@univ.edu       963.555.9067  963.777.4290  Assistant Professor
# 36   ShieldsR@univ.edu       963.555.9197  963.777.7215           Professor
# 37      PageW@univ.edu       963.555.9366  963.777.3202              Curator
# 38    SparksE@univ.edu       963.555.9390  963.777.9273  Assistant Professor
# 39   KaufmanE@univ.edu       963.555.9507  963.777.3298            Professor
#
#     age new_column
# 0    25       None
# 1    23       None
# 2    21       None
# 3    18       None
# 4    30       None
# 5    35       None
# 6    35       None
# 7    35       None
# 8    29       None
# 9    29       None
# 10   28       None
# 11   23       None
# 12   22       None
# 13   22       None
# 14   25       None
# 15   24       None
# 16   25       None
# 17   25       None
# 18   25       None
# 19   25       None
# 20   28       None
# 21   28       None
# 22   28       None
# 23   28       None
# 24   28       None
# 25   25       None
# 26   25       None
# 27   25       None
# 28   25       None
# 29   25       None
# 30   25       None
# 31   25       None
# 32   25       None
# 33   25       None
# 34   25       None
# 35   25       None
# 36   25       None
# 37   25       None
# 38   25       None
# 39   25       None

# %% [markdown]
# ## Hiểu dữ liệu trong df

# %%
peoples_df.describe()
# Out:
#          person_ID        age     birthday
# count    40.000000  40.000000    40.000000
# mean   2702.475000  25.975000  1989.825000
# std     863.183434   3.452888     6.254793
# min    1089.000000  18.000000  1980.000000
# 25%    2133.500000  25.000000  1985.500000
# 50%    2621.500000  25.000000  1989.000000
# 75%    3116.500000  28.000000  1995.500000
# max    4580.000000  35.000000  1999.000000

# %%
# Xem phân bố dữ liệu của thuộc tính 'age'
peoples_df['age'].value_counts()
# Out:
# 25    21
# 28     6
# 35     3
# 29     2
# 23     2
# 22     2
# 30     1
# 24     1
# 21     1
# 18     1
# Name: age, dtype: int64

# %%
# Biểu diễn phân bố dữ liệu của thuộc tính 'age' lên đồ thị
peoples_df['age'].value_counts().plot(kind='bar')

# %% [markdown]
# ## Tạo mới df

# %%
peoples = {'name': ['Nguyễn Văn Hiếu', 'Hiếu Nguyễn Văn'], 'age': [28, 28], 'website': ['https://nguyenvanhieu.vn', None]}
df = pd.DataFrame(peoples)
print(df)
# Out:
#               name  age                   website
# 0  Nguyễn Văn Hiếu   28  https://nguyenvanhieu.vn
# 1  Hiếu Nguyễn Văn   28                      None

# %%
txts = ['chỗ này ăn cũng khá ngon', 'ngon, nhất định sẽ quay lại', 'thái độ phục vụ quá tệ']
labels = [1, 1, 0]
df = pd.DataFrame()
df['txt'] = txts
df['label'] = labels
print(df)
# Out:
#                            txt  label
# 0     chỗ này ăn cũng khá ngon      1
# 1  ngon, nhất định sẽ quay lại      1
# 2       thái độ phục vụ quá tệ      0

# %% [markdown]
# ## Một số thao tác khác

# %%
# Sắp xếp df tăng dần theo cột nào đó
df = pd.DataFrame({'name': ['Nam', 'Hiếu', 'Mai', 'Hoa'], 'age': [18,18,17,19]})
print('Before sort\n', df)
df = df.sort_values('age', ascending=True)
print('After sort\n', df)
# Out:
# Before sort
#     name  age
# 0   Nam   18
# 1  Hiếu   18
# 2   Mai   17
# 3   Hoa   19
# After sort
#     name  age
# 2   Mai   17
# 0   Nam   18
# 1  Hiếu   18
# 3   Hoa   19

# %%
# Gộp 2 dataframe
df1 = pd.DataFrame({'name': ['Hiếu'], 'age': [18], 'gender': ['male']})
df2 = pd.DataFrame({'name': ['Nam', 'Mai', 'Hoa'], 'age': [15,17,19]})
df = df1.append(df2, sort=True)
print(df)
# Out:
#    age gender  name
# 0   18   male  Hiếu
# 0   15    NaN   Nam
# 1   17    NaN   Mai
# 2   19    NaN   Hoa

# %%
# Xáo trộn các hàng trong df - shuffle dataframe rows
df = pd.DataFrame({'name': ['Hiếu', 'Nam', 'Mai', 'Hoa'], 'age': [18,15,17,19]})
print('Before shuffle\n', df)
df = df.sample(frac=1)
print('After shuffle\n', df)
# Out:
# Before shuffle
#     name  age
# 0  Hiếu   18
# 1   Nam   15
# 2   Mai   17
# 3   Hoa   19
# After shuffle
#     name  age
# 0  Hiếu   18
# 3   Hoa   19
# 2   Mai   17
# 1   Nam   15

# %% [markdown]
# ## Lưu dataframe xuống csv file

# %%
df.to_csv('comments.csv')
